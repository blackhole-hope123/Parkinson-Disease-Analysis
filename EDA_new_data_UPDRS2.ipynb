# %% [markdown]
# # Basic Setup and Data Loading

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

# %%
clinical_updrs2 = pd.read_csv("new-data/releases_2023_v4release_1027_clinical_MDS_UPDRS_Part_II.csv")
demographics_new = pd.read_csv("demographics_new.csv")
clinical_updrs2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21385 entries, 0 to 21384
# Data columns (total 32 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   participant_id                                   21385 non-null  object
#  1   GUID                                             13574 non-null  object
#  2   visit_name                                       21385 non-null  object
#  3   visit_month                                      21385 non-null  int64
#  4   mds_updrs_part_ii_primary_info_source            13776 non-null  object
#  5   code_upd2201_speech                              21099 non-null  float64
#  6   code_upd2202_saliva_and_drooling                 20453 non-null  float64
#  7   code_upd2203_chewing_and_swallowing              20453 non-null  float64
#  8   code_upd2204_eating_tasks                        21096 non-null  float64
#  9   code_upd2205_dressing                            21096 non-null  float64
#  10  code_upd2206_hygiene                             20447 non-null  float64
#  11  code_upd2207_handwriting                         20448 non-null  float64
#  12  code_upd2208_doing_hobbies_and_other_activities  20446 non-null  float64
#  13  code_upd2209_turning_in_bed                      20449 non-null  float64
#  14  code_upd2210_tremor                              21096 non-null  float64
#  15  code_upd2211_get_out_of_bed_car_or_deep_chair    20451 non-null  float64
#  16  code_upd2212_walking_and_balance                 20449 non-null  float64
#  17  code_upd2213_freezing                            20450 non-null  float64
#  18  upd2201_speech                                   21099 non-null  object
#  19  upd2202_saliva_and_drooling                      20453 non-null  object
#  20  upd2203_chewing_and_swallowing                   20453 non-null  object
#  21  upd2204_eating_tasks                             21096 non-null  object
#  22  upd2205_dressing                                 21096 non-null  object
#  23  upd2206_hygiene                                  20447 non-null  object
#  24  upd2207_handwriting                              20448 non-null  object
#  25  upd2208_doing_hobbies_and_other_activities       20446 non-null  object
#  26  upd2209_turning_in_bed                           20449 non-null  object
#  27  upd2210_tremor                                   21096 non-null  object
#  28  upd2211_get_out_of_bed_car_or_deep_chair         20451 non-null  object
#  29  upd2212_walking_and_balance                      20449 non-null  object
#  30  upd2213_freezing                                 20450 non-null  object
#  31  mds_updrs_part_ii_summary_score                  20454 non-null  float64
# dtypes: float64(14), int64(1), object(17)
# memory usage: 5.2+ MB

# %%
clinical_updrs2.head()
# Out:
#   participant_id        GUID visit_name  visit_month  \
# 0        BF-1002  PDCB969UGG         M0            0
# 1        BF-1003  PDLW805AHT         M0            0
# 2        BF-1004  PDKW284DYW         M0            0
# 3        BF-1006  PDKY484YDC         M0            0
# 4        BF-1008  PDEA056CRM         M0            0
#
#   mds_updrs_part_ii_primary_info_source  code_upd2201_speech  \
# 0                               Patient                  0.0
# 1                               Patient                  1.0
# 2                               Patient                  0.0
# 3                               Patient                  2.0
# 4                               Patient                  0.0
#
#    code_upd2202_saliva_and_drooling  code_upd2203_chewing_and_swallowing  \
# 0                               3.0                                  1.0
# 1                               2.0                                  0.0
# 2                               2.0                                  0.0
# 3                               1.0                                  0.0
# 4                               0.0                                  0.0
#
#    code_upd2204_eating_tasks  code_upd2205_dressing  ...  upd2205_dressing  \
# 0                        1.0                    1.0  ...            Slight
# 1                        0.0                    1.0  ...            Slight
# 2                        1.0                    1.0  ...            Slight
# 3                        1.0                    2.0  ...              Mild
# 4                        0.0                    0.0  ...            Normal
#
#    upd2206_hygiene  upd2207_handwriting  \
# 0           Slight               Normal
# 1           Slight                 Mild
# 2           Slight               Slight
# 3           Slight               Severe
# 4           Normal               Normal
#
#    upd2208_doing_hobbies_and_other_activities  upd2209_turning_in_bed  \
# 0                                      Normal                  Slight
# 1                                        Mild                  Normal
# 2                                      Slight                  Slight
# 3                                      Normal                  Slight
# 4                                      Normal                  Slight
#
#    upd2210_tremor  upd2211_get_out_of_bed_car_or_deep_chair  \
# 0          Slight                                      Mild
# 1          Slight                                    Normal
# 2          Slight                                    Slight
# 3          Slight                                    Slight
# 4          Slight                                    Slight
#
#    upd2212_walking_and_balance upd2213_freezing  \
# 0                       Normal           Normal
# 1                       Slight           Normal
# 2                       Slight           Normal
# 3                       Normal           Normal
# 4                       Normal           Normal
#
#   mds_updrs_part_ii_summary_score
# 0                            11.0
# 1                            11.0
# 2                            11.0
# 3                            14.0
# 4                             3.0
#
# [5 rows x 32 columns]

# %% [markdown]
# # Data Preprocessing And Cleaning
#
# ## Checking For Duplicates And Nan Values
#
# We begin our analysis by removing patients who have missing (NaN) values in the `GUID` column, as well as those with conflicting identifiers — that is, cases where multiple `participant_id`s share the same `GUID`. To ensure consistency, we retain only the participants whose `participant_id`s appear in the cleaned reference file "demographics_new.csv".

# %%
clinical_updrs2 = clinical_updrs2[clinical_updrs2['participant_id'].isin(demographics_new['participant_id'])]

# %%
clinical_updrs2.nunique()
# Out:
# participant_id                                     3709
# GUID                                               3709
# visit_name                                           20
# visit_month                                          18
# mds_updrs_part_ii_primary_info_source                 3
# code_upd2201_speech                                   5
# code_upd2202_saliva_and_drooling                      5
# code_upd2203_chewing_and_swallowing                   5
# code_upd2204_eating_tasks                             5
# code_upd2205_dressing                                 5
# code_upd2206_hygiene                                  5
# code_upd2207_handwriting                              5
# code_upd2208_doing_hobbies_and_other_activities       5
# code_upd2209_turning_in_bed                           5
# code_upd2210_tremor                                   5
# code_upd2211_get_out_of_bed_car_or_deep_chair         5
# code_upd2212_walking_and_balance                      5
# code_upd2213_freezing                                 5
# upd2201_speech                                        5
# upd2202_saliva_and_drooling                           5
# upd2203_chewing_and_swallowing                        5
# upd2204_eating_tasks                                  5
# upd2205_dressing                                      5
# upd2206_hygiene                                       5
# upd2207_handwriting                                   5
# upd2208_doing_hobbies_and_other_activities            5
# upd2209_turning_in_bed                                5
# upd2210_tremor                                        5
# upd2211_get_out_of_bed_car_or_deep_chair              5
# upd2212_walking_and_balance                           5
# upd2213_freezing                                      5
# mds_updrs_part_ii_summary_score                      51
# dtype: int64

# %%
clinical_updrs2['GUID'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# We remove the GUID column from the dataset, as it is no longer required for the subsequent steps of our analysis. Then we assess the data for duplicate entries by examining combinations of the `participant_id` and `visit_month` columns to ensure each participant's visit is uniquely represented.

# %%
clinical_updrs2.drop('GUID', axis = 1,  inplace = True)

# %%
clinical_updrs2.duplicated(subset = ['visit_month','participant_id']).sum()
# Out:
# np.int64(5)

# %% [markdown]
# Since there are 5 duplicate records based on the combination of `visit_month` and `participant_id`, we need to extract and review all rows where the combination of `visit_month` and `participant_id` are not unique.

# %%
UPDRS1_duplicates =  clinical_updrs2.duplicated(subset=['visit_month', 'participant_id'], keep=False) 
clinical_updrs2[UPDRS1_duplicates]
# Out:
#      participant_id visit_name  visit_month  \
# 6474        PP-3066        M18           18
# 6475        PP-3066      M18#2           18
# 6492        PP-3067        M18           18
# 6493        PP-3067      M18#2           18
# 6602        PP-3078        M18           18
# 6603        PP-3078      M18#2           18
# 7846        PP-3251       M3#2            3
# 7847        PP-3251         M3            3
# 7860        PP-3252       M3#2            3
# 7861        PP-3252         M3            3
#
#      mds_updrs_part_ii_primary_info_source  code_upd2201_speech  \
# 6474                               Patient                  1.0
# 6475                               Patient                  1.0
# 6492                               Patient                  2.0
# 6493                               Patient                  2.0
# 6602                               Patient                  0.0
# 6603                               Patient                  0.0
# 7846                               Patient                  0.0
# 7847                               Patient                  2.0
# 7860                               Patient                  0.0
# 7861                               Patient                  0.0
#
#       code_upd2202_saliva_and_drooling  code_upd2203_chewing_and_swallowing  \
# 6474                               1.0                                  0.0
# 6475                               1.0                                  0.0
# 6492                               0.0                                  0.0
# 6493                               0.0                                  1.0
# 6602                               0.0                                  0.0
# 6603                               0.0                                  0.0
# 7846                               0.0                                  1.0
# 7847                               0.0                                  1.0
# 7860                               0.0                                  0.0
# 7861                               0.0                                  0.0
#
#       code_upd2204_eating_tasks  code_upd2205_dressing  code_upd2206_hygiene  \
# 6474                        1.0                    1.0                   1.0
# 6475                        1.0                    1.0                   1.0
# 6492                        1.0                    1.0                   0.0
# 6493                        1.0                    0.0                   0.0
# 6602                        1.0                    0.0                   0.0
# 6603                        1.0                    1.0                   1.0
# 7846                        0.0                    1.0                   1.0
# 7847                        0.0                    0.0                   1.0
# 7860                        1.0                    1.0                   1.0
# 7861                        1.0                    1.0                   1.0
#
#       ...  upd2205_dressing  upd2206_hygiene  upd2207_handwriting  \
# 6474  ...            Slight           Slight               Slight
# 6475  ...            Slight           Slight               Slight
# 6492  ...            Slight           Normal               Severe
# 6493  ...            Normal           Normal             Moderate
# 6602  ...            Normal           Normal               Slight
# 6603  ...            Slight           Slight               Slight
# 7846  ...            Slight           Slight               Normal
# 7847  ...            Normal           Slight               Normal
# 7860  ...            Slight           Slight               Slight
# 7861  ...            Slight           Slight               Slight
#
#       upd2208_doing_hobbies_and_other_activities  upd2209_turning_in_bed  \
# 6474                                      Slight                  Slight
# 6475                                        Mild                  Slight
# 6492                                    Moderate                  Normal
# 6493                                      Normal                  Normal
# 6602                                      Slight                  Normal
# 6603                                      Slight                  Normal
# 7846                                      Slight                  Slight
# 7847                                      Normal                  Normal
# 7860                                      Slight                  Slight
# 7861                                      Slight                  Slight
#
#       upd2210_tremor  upd2211_get_out_of_bed_car_or_deep_chair  \
# 6474            Mild                                    Slight
# 6475            Mild                                      Mild
# 6492            Mild                                    Slight
# 6493            Mild                                    Normal
# 6602            Mild                                    Normal
# 6603            Mild                                    Normal
# 7846          Slight                                      Mild
# 7847          Slight                                    Slight
# 7860          Slight                                    Normal
# 7861          Slight                                    Slight
#
#      upd2212_walking_and_balance upd2213_freezing  \
# 6474                      Slight           Slight
# 6475                      Slight           Slight
# 6492                      Normal           Normal
# 6493                      Normal           Normal
# 6602                      Normal           Normal
# 6603                      Normal           Normal
# 7846                      Slight             Mild
# 7847                      Slight           Normal
# 7860                      Slight           Slight
# 7861                      Slight           Normal
#
#      mds_updrs_part_ii_summary_score
# 6474                            13.0
# 6475                            15.0
# 6492                            14.0
# 6493                             9.0
# 6602                             5.0
# 6603                             7.0
# 7846                            11.0
# 7847                             7.0
# 7860                             9.0
# 7861                             9.0
#
# [10 rows x 31 columns]

# %% [markdown]
# The analysis indicates that there are no genuine duplicates, as the repeated entries are due to multiple visits by the same participant, which can be seen in the `visit_name` column.
